# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
#from scipy.stats import linregress
from scipy.stats import pearsonr, linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

import datetime

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 586

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []
units = "metric"

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    query_city_url = (f"{url}appid={weather_api_key}&units={units}&q=+{city}")
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(query_city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | iqaluit
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | flin flon
# Processing Record 4 of Set 1 | kanoya
# Processing Record 5 of Set 1 | san matias
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | grytviken
# Processing Record 8 of Set 1 | vila velha
# Processing Record 9 of Set 1 | iskateley
# Processing Record 10 of Set 1 | talnakh
# Processing Record 11 of Set 1 | port-aux-francais
# Processing Record 12 of Set 1 | palmer
# Processing Record 13 of Set 1 | villa nueva
# Processing Record 14 of Set 1 | tepatitlan de morelos
# Processing Record 15 of Set 1 | tadine
# Processing Record 16 of Set 1 | sete
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | adamstown
# Processing Record 19 of Set 1 | susuman
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | blackmans bay
# Processing Record 22 of Set 1 | christchurch
# Processing Record 23 of Set 1 | oban
# Processing Record 24 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | ust-nera
# Processing Record 27 of Set 1 | petropavlovsk-kamchatsky
# City not found. Skipping...
# Processing Record 28 of Set 1 | mukalla
# City not found. Skipping...
# Processing Record 29 of Set 1 | lubango
# Processing Record 30 of Set 1 | chonchi
# Processing Record 31 of Set 1 | katsuren-haebaru
# City not found. Skipping...
# Processing Record 32 of Set 1 | mount pearl
# Processing Record 33 of Set 1 | west island
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | rio grande
# Processing Record 36 of Set 1 | arraial do cabo
# Processing Record 37 of Set 1 | sadjoavato
# City not found. Skipping...
# Processing Record 38 of Set 1 | hamilton
# Processing Record 39 of Set 1 | tottori
# Processing Record 40 of Set 1 | edinburgh of the seven seas
# Processing Record 41 of Set 1 | bilibino
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | fort mcmurray
# Processing Record 44 of Set 1 | isafjordur
# City not found. Skipping...
# Processing Record 45 of Set 1 | keflavik
# Processing Record 46 of Set 1 | okhotsk
# Processing Record 47 of Set 1 | waitangi
# Processing Record 48 of Set 1 | uturoa
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | pervomayskoye
# Processing Record 0 of Set 2 | hawaiian paradise park
# Processing Record 1 of Set 2 | kyzyl-mazhalyk
# Processing Record 2 of Set 2 | constantia
# Processing Record 3 of Set 2 | waddan
# Processing Record 4 of Set 2 | port mathurin
# Processing Record 5 of Set 2 | saudarkrokur
# Processing Record 6 of Set 2 | kolonia town
# Processing Record 7 of Set 2 | tongliao
# Processing Record 8 of Set 2 | badger
# Processing Record 9 of Set 2 | nadi
# Processing Record 10 of Set 2 | north platte
# Processing Record 11 of Set 2 | muzayri'
# City not found. Skipping...
# Processing Record 12 of Set 2 | kailua-kona
# Processing Record 13 of Set 2 | tura
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | stung treng
# City not found. Skipping...
# Processing Record 16 of Set 2 | puerto natales
# Processing Record 17 of Set 2 | midvagur
# Processing Record 18 of Set 2 | macapa
# Processing Record 19 of Set 2 | isla vista
# Processing Record 20 of Set 2 | nikolayevsk-on-amure
# City not found. Skipping...
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | roma
# Processing Record 23 of Set 2 | loukhi
# Processing Record 24 of Set 2 | curuca
# Processing Record 25 of Set 2 | ban karon
# Processing Record 26 of Set 2 | tiksi
# Processing Record 27 of Set 2 | kingston
# Processing Record 28 of Set 2 | margaret river
# Processing Record 29 of Set 2 | utrik
# Processing Record 30 of Set 2 | isiolo
# Processing Record 31 of Set 2 | lorengau
# Processing Record 32 of Set 2 | worthing
# Processing Record 33 of Set 2 | north bay
# Processing Record 34 of Set 2 | kipushi
# Processing Record 35 of Set 2 | minas de marcona
# Processing Record 36 of Set 2 | houghton
# Processing Record 37 of Set 2 | invercargill
# Processing Record 38 of Set 2 | xiongzhou
# Processing Record 39 of Set 2 | jumla
# Processing Record 40 of Set 2 | puerto deseado
# Processing Record 41 of Set 2 | mahibadhoo
# Processing Record 42 of Set 2 | wailua homesteads
# Processing Record 43 of Set 2 | college
# Processing Record 44 of Set 2 | luderitz
# Processing Record 45 of Set 2 | stanley
# Processing Record 46 of Set 2 | hays
# Processing Record 47 of Set 2 | greymouth
# Processing Record 48 of Set 2 | mount isa
# Processing Record 49 of Set 2 | baoqing
# Processing Record 0 of Set 3 | koryazhma
# Processing Record 1 of Set 3 | hilo
# Processing Record 2 of Set 3 | ilulissat
# Processing Record 3 of Set 3 | yerofey pavlovich
# Processing Record 4 of Set 3 | taulaga
# Processing Record 5 of Set 3 | ushuaia
# Processing Record 6 of Set 3 | gorontalo
# Processing Record 7 of Set 3 | fort bragg
# Processing Record 8 of Set 3 | dryden
# Processing Record 9 of Set 3 | jiuquan
# City not found. Skipping...
# Processing Record 10 of Set 3 | beira
# Processing Record 11 of Set 3 | ribeira grande
# Processing Record 12 of Set 3 | avarua
# Processing Record 13 of Set 3 | togur
# Processing Record 14 of Set 3 | konstantinovka
# Processing Record 15 of Set 3 | sal rei
# Processing Record 16 of Set 3 | tuy hoa
# Processing Record 17 of Set 3 | anadyr
# Processing Record 18 of Set 3 | queenstown
# Processing Record 19 of Set 3 | east london
# Processing Record 20 of Set 3 | mount gambier
# Processing Record 21 of Set 3 | bredasdorp
# Processing Record 22 of Set 3 | edinboro
# Processing Record 23 of Set 3 | kyelang
# Processing Record 24 of Set 3 | vorgashor
# Processing Record 25 of Set 3 | riacho de santana
# Processing Record 26 of Set 3 | kimbe
# Processing Record 27 of Set 3 | fale old settlement
# Processing Record 28 of Set 3 | kudahuvadhoo
# Processing Record 29 of Set 3 | lerwick
# Processing Record 30 of Set 3 | hasaki
# Processing Record 31 of Set 3 | sinabang
# Processing Record 32 of Set 3 | angaur state
# Processing Record 33 of Set 3 | hermanus
# Processing Record 34 of Set 3 | pisco
# Processing Record 35 of Set 3 | kapuskasing
# Processing Record 36 of Set 3 | tazovsky
# City not found. Skipping...
# Processing Record 37 of Set 3 | santa ana
# Processing Record 38 of Set 3 | ndele
# Processing Record 39 of Set 3 | aasiaat
# Processing Record 40 of Set 3 | lesnikovo
# Processing Record 41 of Set 3 | villa gesell
# Processing Record 42 of Set 3 | itoman
# Processing Record 43 of Set 3 | quibala
# Processing Record 44 of Set 3 | yilan
# Processing Record 45 of Set 3 | san patricio
# Processing Record 46 of Set 3 | olonkinbyen
# Processing Record 47 of Set 3 | nuuk
# Processing Record 48 of Set 3 | zeya
# Processing Record 49 of Set 3 | addiet canna
# Processing Record 0 of Set 4 | vyazemskiy
# Processing Record 1 of Set 4 | bazarnyy karabulak
# Processing Record 2 of Set 4 | kataragama
# City not found. Skipping...
# Processing Record 3 of Set 4 | ulysses
# Processing Record 4 of Set 4 | san mariano
# Processing Record 5 of Set 4 | qaqortoq
# Processing Record 6 of Set 4 | karbala
# Processing Record 7 of Set 4 | alice springs
# Processing Record 8 of Set 4 | sake
# Processing Record 9 of Set 4 | sinop
# Processing Record 10 of Set 4 | vadso
# Processing Record 11 of Set 4 | barwani
# Processing Record 12 of Set 4 | ancud
# Processing Record 13 of Set 4 | arica
# Processing Record 14 of Set 4 | nova sintra
# City not found. Skipping...
# Processing Record 15 of Set 4 | fada
# City not found. Skipping...
# Processing Record 16 of Set 4 | la ronge
# Processing Record 17 of Set 4 | saint-pol-sur-ternoise
# Processing Record 18 of Set 4 | nyurba
# Processing Record 19 of Set 4 | guymon
# Processing Record 20 of Set 4 | vizinga
# Processing Record 21 of Set 4 | kourou
# Processing Record 22 of Set 4 | gisborne
# Processing Record 23 of Set 4 | smithers
# Processing Record 24 of Set 4 | afaahiti
# Processing Record 25 of Set 4 | la passe
# City not found. Skipping...
# Processing Record 26 of Set 4 | al marj
# Processing Record 27 of Set 4 | okha
# Processing Record 28 of Set 4 | revda
# Processing Record 29 of Set 4 | kumagunnam
# Processing Record 30 of Set 4 | gulf shores
# Processing Record 31 of Set 4 | saipan
# Processing Record 32 of Set 4 | nizhneudinsk
# Processing Record 33 of Set 4 | longyearbyen
# Processing Record 34 of Set 4 | mbala
# Processing Record 35 of Set 4 | biltine
# Processing Record 36 of Set 4 | kannus
# Processing Record 37 of Set 4 | port elizabeth
# Processing Record 38 of Set 4 | gadzhiyevo
# Processing Record 39 of Set 4 | ebon
# Processing Record 40 of Set 4 | hadibu
# City not found. Skipping...
# Processing Record 41 of Set 4 | vorkuta
# Processing Record 42 of Set 4 | saint-francois
# Processing Record 43 of Set 4 | ta`u
# City not found. Skipping...
# Processing Record 44 of Set 4 | alicante
# Processing Record 45 of Set 4 | boguchany
# Processing Record 46 of Set 4 | halden
# Processing Record 47 of Set 4 | altai
# Processing Record 48 of Set 4 | pocone
# Processing Record 49 of Set 4 | xilin hot
# Processing Record 0 of Set 5 | whitehorse
# Processing Record 1 of Set 5 | opatow
# Processing Record 2 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 3 of Set 5 | haiku-pauwela
# Processing Record 4 of Set 5 | barah
# Processing Record 5 of Set 5 | val-d'or
# City not found. Skipping...
# Processing Record 6 of Set 5 | itaituba
# Processing Record 7 of Set 5 | visby
# Processing Record 8 of Set 5 | new norfolk
# Processing Record 9 of Set 5 | papatowai
# City not found. Skipping...
# Processing Record 10 of Set 5 | codrington
# Processing Record 11 of Set 5 | flying fish cove
# Processing Record 12 of Set 5 | cestos city
# City not found. Skipping...
# Processing Record 13 of Set 5 | karpenisi
# Processing Record 14 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 15 of Set 5 | san antonio de pale
# City not found. Skipping...
# Processing Record 16 of Set 5 | ramnagar
# Processing Record 17 of Set 5 | klyuchi
# Processing Record 18 of Set 5 | st. john's
# City not found. Skipping...
# Processing Record 19 of Set 5 | giado
# Processing Record 20 of Set 5 | zapala
# Processing Record 21 of Set 5 | bhamo
# Processing Record 22 of Set 5 | agat village
# Processing Record 23 of Set 5 | cabo san lucas
# Processing Record 24 of Set 5 | hamirpur
# Processing Record 25 of Set 5 | walvis bay
# Processing Record 26 of Set 5 | dawson creek
# Processing Record 27 of Set 5 | sadovoye
# Processing Record 28 of Set 5 | galesong
# Processing Record 29 of Set 5 | la'ie
# City not found. Skipping...
# Processing Record 30 of Set 5 | choibalsan
# City not found. Skipping...
# Processing Record 31 of Set 5 | vilyuysk
# Processing Record 32 of Set 5 | masindi
# Processing Record 33 of Set 5 | tolanaro
# City not found. Skipping...
# Processing Record 34 of Set 5 | itacarambi
# Processing Record 35 of Set 5 | wynyard
# Processing Record 36 of Set 5 | hithadhoo
# Processing Record 37 of Set 5 | nogliki
# Processing Record 38 of Set 5 | isangel
# Processing Record 39 of Set 5 | santiago de cao
# Processing Record 40 of Set 5 | laurel
# Processing Record 41 of Set 5 | remire-montjoly
# Processing Record 42 of Set 5 | olean
# Processing Record 43 of Set 5 | rabigh
# Processing Record 44 of Set 5 | emerald
# Processing Record 45 of Set 5 | amahai
# Processing Record 46 of Set 5 | ulsteinvik
# Processing Record 47 of Set 5 | sechura
# Processing Record 48 of Set 5 | muroto-misakicho
# City not found. Skipping...
# Processing Record 49 of Set 5 | kone
# Processing Record 0 of Set 6 | beloyarskiy
# Processing Record 1 of Set 6 | manturovo
# Processing Record 2 of Set 6 | muana
# Processing Record 3 of Set 6 | galliano
# Processing Record 4 of Set 6 | superior
# Processing Record 5 of Set 6 | ahau
# City not found. Skipping...
# Processing Record 6 of Set 6 | belyy yar
# Processing Record 7 of Set 6 | nantucket
# Processing Record 8 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 9 of Set 6 | kokopo
# Processing Record 10 of Set 6 | abepura
# Processing Record 11 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 12 of Set 6 | ojinaga
# Processing Record 13 of Set 6 | al ghayzah
# Processing Record 14 of Set 6 | karaidel'
# City not found. Skipping...
# Processing Record 15 of Set 6 | el porvenir
# Processing Record 16 of Set 6 | kununurra
# Processing Record 17 of Set 6 | cozumel
# City not found. Skipping...
# Processing Record 18 of Set 6 | kichmengskiy gorodok
# Processing Record 19 of Set 6 | voskresenskoye
# Processing Record 20 of Set 6 | laikit, laikit ii (dimembe)
# City not found. Skipping...
# Processing Record 21 of Set 6 | huangmei
# Processing Record 22 of Set 6 | harper
# Processing Record 23 of Set 6 | enewetak
# Processing Record 24 of Set 6 | misratah
# Processing Record 25 of Set 6 | cockburn town
# Processing Record 26 of Set 6 | dudinka
# Processing Record 27 of Set 6 | al bawiti
# Processing Record 28 of Set 6 | cradock
# Processing Record 29 of Set 6 | koidu
# Processing Record 30 of Set 6 | buka
# Processing Record 31 of Set 6 | waterloo
# Processing Record 32 of Set 6 | chu
# City not found. Skipping...
# Processing Record 33 of Set 6 | wanning
# Processing Record 34 of Set 6 | naze
# Processing Record 35 of Set 6 | we
# Processing Record 36 of Set 6 | seaside
# Processing Record 37 of Set 6 | atafu village
# Processing Record 38 of Set 6 | mogadishu
# Processing Record 39 of Set 6 | santa flavia
# Processing Record 40 of Set 6 | elverum
# Processing Record 41 of Set 6 | sidareja
# Processing Record 42 of Set 6 | callao
# Processing Record 43 of Set 6 | taoudenni
# Processing Record 44 of Set 6 | saynshand
# Processing Record 45 of Set 6 | barinitas
# Processing Record 46 of Set 6 | yarmouth
# Processing Record 47 of Set 6 | kongolo
# Processing Record 48 of Set 6 | bel ombre
# Processing Record 49 of Set 6 | presidente medici
# Processing Record 0 of Set 7 | port alfred
# Processing Record 1 of Set 7 | gutao
# Processing Record 2 of Set 7 | lihue
# Processing Record 3 of Set 7 | petrovsk-zabaykal'skiy
# City not found. Skipping...
# Processing Record 4 of Set 7 | ola
# Processing Record 5 of Set 7 | i-n-salah
# Processing Record 6 of Set 7 | ponta delgada
# Processing Record 7 of Set 7 | kenai
# Processing Record 8 of Set 7 | fayroz koh
# City not found. Skipping...
# Processing Record 9 of Set 7 | karatuzskoye
# Processing Record 10 of Set 7 | san vicente de chucuri
# Processing Record 11 of Set 7 | mitsamiouli
# Processing Record 12 of Set 7 | fortuna
# Processing Record 13 of Set 7 | saldanha
# Processing Record 14 of Set 7 | weno
# City not found. Skipping...
# Processing Record 15 of Set 7 | sishilichengzi
# City not found. Skipping...
# Processing Record 16 of Set 7 | cacoal
# Processing Record 17 of Set 7 | sovetskaya gavan'
# City not found. Skipping...
# Processing Record 18 of Set 7 | sibolga
# Processing Record 19 of Set 7 | tsiombe
# Processing Record 20 of Set 7 | sangmelima
# Processing Record 21 of Set 7 | san jose del guaviare
# Processing Record 22 of Set 7 | loango
# City not found. Skipping...
# Processing Record 23 of Set 7 | yuzhno-kurilsk
# Processing Record 24 of Set 7 | al minya
# Processing Record 25 of Set 7 | antonio enes
# Processing Record 26 of Set 7 | port arthur
# Processing Record 27 of Set 7 | gandajika
# Processing Record 28 of Set 7 | hammerfest
# Processing Record 29 of Set 7 | imbituba
# Processing Record 30 of Set 7 | banamba
# Processing Record 31 of Set 7 | prado
# Processing Record 32 of Set 7 | xghajra
# City not found. Skipping...
# Processing Record 33 of Set 7 | brisas de zicatela
# City not found. Skipping...
# Processing Record 34 of Set 7 | tobi village
# City not found. Skipping...
# Processing Record 35 of Set 7 | chibougamau
# Processing Record 36 of Set 7 | mugia
# Processing Record 37 of Set 7 | natal
# Processing Record 38 of Set 7 | geraldton
# Processing Record 39 of Set 7 | santa cruz
# Processing Record 40 of Set 7 | hotan
# Processing Record 41 of Set 7 | juru
# Processing Record 42 of Set 7 | east honolulu
# City not found. Skipping...
# Processing Record 43 of Set 7 | marsabit
# Processing Record 44 of Set 7 | mermoz boabab
# Processing Record 45 of Set 7 | akureyri
# Processing Record 46 of Set 7 | malvan
# Processing Record 47 of Set 7 | lampazos de naranjo
# Processing Record 48 of Set 7 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 49 of Set 7 | holdrege
# Processing Record 0 of Set 8 | udachny
# City not found. Skipping...
# Processing Record 1 of Set 8 | tete
# Processing Record 2 of Set 8 | bukittinggi
# Processing Record 3 of Set 8 | rongelap
# Processing Record 4 of Set 8 | bushland beach
# City not found. Skipping...
# Processing Record 5 of Set 8 | lensk
# Processing Record 6 of Set 8 | quelimane
# Processing Record 7 of Set 8 | kitami
# Processing Record 8 of Set 8 | cooper's town
# City not found. Skipping...
# Processing Record 9 of Set 8 | arendal
# Processing Record 10 of Set 8 | gorokhovets
# Processing Record 11 of Set 8 | tongren
# Processing Record 12 of Set 8 | effingham
# Processing Record 13 of Set 8 | guerrero negro
# Processing Record 14 of Set 8 | pursat
# Processing Record 15 of Set 8 | corinto
# Processing Record 16 of Set 8 | lodja
# Processing Record 17 of Set 8 | alesund
# Processing Record 18 of Set 8 | batu pahat
# Processing Record 19 of Set 8 | qujing
# Processing Record 20 of Set 8 | daru
# Processing Record 21 of Set 8 | bijie
# Processing Record 22 of Set 8 | margate
# Processing Record 23 of Set 8 | jacmel
# Processing Record 24 of Set 8 | port blair
# Processing Record 25 of Set 8 | puri
# Processing Record 26 of Set 8 | kayangel
# Processing Record 27 of Set 8 | recani
# City not found. Skipping...
# Processing Record 28 of Set 8 | asau
# Processing Record 29 of Set 8 | sitka
# Processing Record 30 of Set 8 | kirakira
# Processing Record 31 of Set 8 | mejit
# Processing Record 32 of Set 8 | whakatane
# Processing Record 33 of Set 8 | sept-iles
# Processing Record 34 of Set 8 | vilyuchinsk
# Processing Record 35 of Set 8 | port isabel
# Processing Record 36 of Set 8 | sisimiut
# Processing Record 37 of Set 8 | gypsum
# Processing Record 38 of Set 8 | dubai
# Processing Record 39 of Set 8 | saint-denis
# Processing Record 40 of Set 8 | mesyagutovo
# Processing Record 41 of Set 8 | elmendorf air force base
# City not found. Skipping...
# Processing Record 42 of Set 8 | ouellah
# City not found. Skipping...
# Processing Record 43 of Set 8 | lodwar
# Processing Record 44 of Set 8 | khorixas
# Processing Record 45 of Set 8 | punta del este
# Processing Record 46 of Set 8 | oranjemund
# Processing Record 47 of Set 8 | port antonio
# Processing Record 48 of Set 8 | ngaoundere
# Processing Record 49 of Set 8 | shimokizukuri
# City not found. Skipping...
# Processing Record 0 of Set 9 | ijuw
# City not found. Skipping...
# Processing Record 1 of Set 9 | cobourg
# Processing Record 2 of Set 9 | fisterra
# Processing Record 3 of Set 9 | kidal
# Processing Record 4 of Set 9 | beypore
# Processing Record 5 of Set 9 | bubaque
# Processing Record 6 of Set 9 | claveria
# Processing Record 7 of Set 9 | kaspiyskiy
# Processing Record 8 of Set 9 | sungai raya
# City not found. Skipping...
# Processing Record 9 of Set 9 | vila franca do campo
# Processing Record 10 of Set 9 | terbanggi besar
# City not found. Skipping...
# Processing Record 11 of Set 9 | brookings
# Processing Record 12 of Set 9 | san pablo villa de mitla
# Processing Record 13 of Set 9 | saacow
# Processing Record 14 of Set 9 | paita
# Processing Record 15 of Set 9 | asmar
# Processing Record 16 of Set 9 | shalqar
# Processing Record 17 of Set 9 | debark'
# City not found. Skipping...
# Processing Record 18 of Set 9 | kitimat
# Processing Record 19 of Set 9 | yeppoon
# Processing Record 20 of Set 9 | gamba
# Processing Record 21 of Set 9 | thinadhoo
# Processing Record 22 of Set 9 | baruun-urt
# Processing Record 23 of Set 9 | carnarvon
# Processing Record 24 of Set 9 | karpinsk
# Processing Record 25 of Set 9 | ciudad lazaro cardenas
# City not found. Skipping...
# Processing Record 26 of Set 9 | crane
# Processing Record 27 of Set 9 | longford
# Processing Record 28 of Set 9 | neon karlovasion
# Processing Record 29 of Set 9 | aromashevo
# Processing Record 30 of Set 9 | port lincoln
# Processing Record 31 of Set 9 | salinopolis
# Processing Record 32 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 33 of Set 9 | reidsville
# Processing Record 34 of Set 9 | rosarito
# Processing Record 35 of Set 9 | iwanai
# Processing Record 36 of Set 9 | borogontsy
# Processing Record 37 of Set 9 | betio village
# Processing Record 38 of Set 9 | bystrzyca klodzka
# Processing Record 39 of Set 9 | sao joao da barra
# Processing Record 40 of Set 9 | shangri-la
# City not found. Skipping...
# Processing Record 41 of Set 9 | karasburg
# Processing Record 42 of Set 9 | sabang
# Processing Record 43 of Set 9 | orange cove
# Processing Record 44 of Set 9 | necochea
# Processing Record 45 of Set 9 | yamada
# Processing Record 46 of Set 9 | nova vicosa
# Processing Record 47 of Set 9 | ichinoseki
# Processing Record 48 of Set 9 | lasem
# Processing Record 49 of Set 9 | sao paulo de olivenca
# Processing Record 0 of Set 10 | bukama
# Processing Record 1 of Set 10 | konakovo
# Processing Record 2 of Set 10 | selkirk
# Processing Record 3 of Set 10 | puerto aysen
# City not found. Skipping...
# Processing Record 4 of Set 10 | anavyssos
# Processing Record 5 of Set 10 | karatas
# Processing Record 6 of Set 10 | vel'sk
# City not found. Skipping...
# Processing Record 7 of Set 10 | alofi
# Processing Record 8 of Set 10 | hovd
# Processing Record 9 of Set 10 | gantang
# Processing Record 10 of Set 10 | lata
# Processing Record 11 of Set 10 | roussillon
# Processing Record 12 of Set 10 | tofol
# Processing Record 13 of Set 10 | el calafate
# Processing Record 14 of Set 10 | fort pierce
# Processing Record 15 of Set 10 | adam
# Processing Record 16 of Set 10 | wewak
# Processing Record 17 of Set 10 | cill airne
# Processing Record 18 of Set 10 | mariehamn
# Processing Record 19 of Set 10 | anbyon-up
# Processing Record 20 of Set 10 | broken hill
# Processing Record 21 of Set 10 | kudymkar
# Processing Record 22 of Set 10 | acarau
# Processing Record 23 of Set 10 | monrovia
# Processing Record 24 of Set 10 | berezovyy
# Processing Record 25 of Set 10 | colonia
# Processing Record 26 of Set 10 | fauske
# Processing Record 27 of Set 10 | oriximina
# Processing Record 28 of Set 10 | manokwari
# Processing Record 29 of Set 10 | kavaratti
# Processing Record 30 of Set 10 | veinticinco de mayo
# Processing Record 31 of Set 10 | rantauprapat
# Processing Record 32 of Set 10 | tamanrasset
# Processing Record 33 of Set 10 | spring creek
# Processing Record 34 of Set 10 | mega
# Processing Record 35 of Set 10 | egilsstadir
# Processing Record 36 of Set 10 | kalmunai
# Processing Record 37 of Set 10 | nagqu
# Processing Record 38 of Set 10 | brokopondo
# Processing Record 39 of Set 10 | vanimo
# Processing Record 40 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 41 of Set 10 | kietrz
# Processing Record 42 of Set 10 | boundiali
# Processing Record 43 of Set 10 | nihommatsu
# Processing Record 44 of Set 10 | aripuana
# Processing Record 45 of Set 10 | daura
# Processing Record 46 of Set 10 | saint-leu
# Processing Record 47 of Set 10 | la paz
# Processing Record 48 of Set 10 | xianyang
# Processing Record 49 of Set 10 | zaozersk
# Processing Record 0 of Set 11 | shingu
# Processing Record 1 of Set 11 | pohrebyshche
# Processing Record 2 of Set 11 | chifeng
# Processing Record 3 of Set 11 | sur
# Processing Record 4 of Set 11 | litchfield
# Processing Record 5 of Set 11 | krasnoarmeyskoye
# Processing Record 6 of Set 11 | al jawf
# Processing Record 7 of Set 11 | ilovlya
# Processing Record 8 of Set 11 | madinat sittah uktubar
# Processing Record 9 of Set 11 | santa elena de uairen
# Processing Record 10 of Set 11 | dishna
# Processing Record 11 of Set 11 | santa terezinha
# City not found. Skipping...
# Processing Record 12 of Set 11 | pressbaum
# Processing Record 13 of Set 11 | zemio
# Processing Record 14 of Set 11 | ascension
# Processing Record 15 of Set 11 | aytos
# Processing Record 16 of Set 11 | rio verde de mato grosso
# Processing Record 17 of Set 11 | runing
# City not found. Skipping...
# Processing Record 18 of Set 11 | bajos de haina
# Processing Record 19 of Set 11 | dunedin
# Processing Record 20 of Set 11 | dan sadau
# Processing Record 21 of Set 11 | caucete
# Processing Record 22 of Set 11 | bardai
# City not found. Skipping...
# Processing Record 23 of Set 11 | guachochi
# City not found. Skipping...
# Processing Record 24 of Set 11 | yermentau
# City not found. Skipping...
# Processing Record 25 of Set 11 | paithan
# Processing Record 26 of Set 11 | bodo
# Processing Record 27 of Set 11 | marechal floriano
# Processing Record 28 of Set 11 | shiqian
# Processing Record 29 of Set 11 | madalena
# Processing Record 30 of Set 11 | kiunga
# Processing Record 31 of Set 11 | awjilah
# Processing Record 32 of Set 11 | vinzons
# Processing Record 33 of Set 11 | vanino
# Processing Record 34 of Set 11 | kyabe
# Processing Record 35 of Set 11 | namibe
# Processing Record 36 of Set 11 | capao da canoa
# Processing Record 37 of Set 11 | marco island
# City not found. Skipping...
# Processing Record 38 of Set 11 | evergreen
# Processing Record 39 of Set 11 | ataq
# Processing Record 40 of Set 11 | sultanpur
# Processing Record 41 of Set 11 | linxia chengguanzhen
# City not found. Skipping...
# Processing Record 42 of Set 11 | papao
# Processing Record 43 of Set 11 | magburaka
# Processing Record 44 of Set 11 | taroa
# Processing Record 45 of Set 11 | kotovo
# Processing Record 46 of Set 11 | el eulma
# Processing Record 47 of Set 11 | gallneukirchen
# Processing Record 48 of Set 11 | ha'il
# City not found. Skipping...
# Processing Record 49 of Set 11 | dabakala
# Processing Record 0 of Set 12 | rio san juan
# Processing Record 1 of Set 12 | bahla'
# City not found. Skipping...
# Processing Record 2 of Set 12 | al bardiyah
# City not found. Skipping...
# Processing Record 3 of Set 12 | nchelenge
# Processing Record 4 of Set 12 | dambatta
# City not found. Skipping...
# Processing Record 5 of Set 12 | quellon
# City not found. Skipping...
# Processing Record 6 of Set 12 | dickinson
# Processing Record 7 of Set 12 | piensk
# Processing Record 8 of Set 12 | merizo village
# Processing Record 9 of Set 12 | ocean city
# Processing Record 10 of Set 12 | arish
# City not found. Skipping...
# Processing Record 11 of Set 12 | saint-pierre
# Processing Record 12 of Set 12 | shumikha
# Processing Record 13 of Set 12 | kegeyli shahar
# Processing Record 14 of Set 12 | bulawayo
# Processing Record 15 of Set 12 | labuan
# Processing Record 16 of Set 12 | sampit
# Processing Record 17 of Set 12 | ilhabela
# Processing Record 18 of Set 12 | kembe
# Processing Record 19 of Set 12 | ca mau
# Processing Record 20 of Set 12 | tyul'gan
# City not found. Skipping...
# Processing Record 21 of Set 12 | dyatlovo
# City not found. Skipping...
# Processing Record 22 of Set 12 | tanout
# Processing Record 23 of Set 12 | trinidad
# Processing Record 24 of Set 12 | slave lake
# Processing Record 25 of Set 12 | vallenar
# Processing Record 26 of Set 12 | leava
# City not found. Skipping...
# Processing Record 27 of Set 12 | bredy
# Processing Record 28 of Set 12 | moree
# Processing Record 29 of Set 12 | sotik post
# City not found. Skipping...
# Processing Record 30 of Set 12 | katsuura
# Processing Record 31 of Set 12 | itamaraca
# Processing Record 32 of Set 12 | labasa
# City not found. Skipping...
# Processing Record 33 of Set 12 | coquimbo
# Processing Record 34 of Set 12 | howard springs
# City not found. Skipping...
# Processing Record 35 of Set 12 | yunyang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          504
# Lat           504
# Lng           504
# Max Temp      504
# Humidity      504
# Cloudiness    504
# Wind Speed    504
# Country       504
# Date          504
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       iqaluit  63.7506  -68.5145     -0.15       100         100
# 1  punta arenas -53.1500  -70.9167      6.06        87         100
# 2     flin flon  54.7682 -101.8650     -3.38        92          36
# 3        kanoya  31.3833  130.8500     17.54        58         100
# 4    san matias -16.3667  -58.4000     22.53        88          48
#
#    Wind Speed Country        Date
# 0        2.57      CA  1682310506
# 1        5.14      CL  1682310506
# 2        2.48      CA  1682310506
# 3        5.88      JP  1682310506
# 4        0.72      BO  1682310507

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             iqaluit  63.7506  -68.5145     -0.15       100         100
# 1        punta arenas -53.1500  -70.9167      6.06        87         100
# 2           flin flon  54.7682 -101.8650     -3.38        92          36
# 3              kanoya  31.3833  130.8500     17.54        58         100
# 4          san matias -16.3667  -58.4000     22.53        88          48
#
#          Wind Speed Country        Date
# City_ID
# 0              2.57      CA  1682310506
# 1              5.14      CL  1682310506
# 2              2.48      CA  1682310506
# 3              5.88      JP  1682310506
# 4              0.72      BO  1682310507

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot.scatter(x="Lat", y="Max Temp",c='blue', edgecolor='red')

timestamp = city_data_df.loc[1,'Date']
date = datetime.datetime.fromtimestamp(timestamp)
print(date)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Max Latitude vs Temperature " + str(date))
plt.grid()

# Save the figure
plt.savefig("zzz_Fig1.png")

# Show plot
plt.show()
# Out:
# 2023-04-24 00:28:26

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot.scatter(x="Lat", y="Humidity",c='red',edgecolor='black')

timestamp = city_data_df.loc[1,'Date']
date = datetime.datetime.fromtimestamp(timestamp)
print(date)


# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Max Latitude vs Humidity (% ) " + str(date))
plt.grid()

# Save the figure
plt.savefig("zzzFig2.png")

# Show plot
plt.show()
# Out:
# 2023-04-24 00:28:26

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot.scatter(x="Lat", y="Cloudiness",c='purple',edgecolor='blue')

timestamp = city_data_df.loc[1,'Date']
date = datetime.datetime.fromtimestamp(timestamp)
print(date)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Max Latitude vs Cloudiness (%) " + str(date))
plt.grid()


# Save the figure
plt.savefig("zzzFig3.png")

# Show plot
plt.show()
# Out:
# 2023-04-24 00:28:26

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot.scatter(x="Lat", y="Wind Speed",c='black',edgecolor='red')

timestamp = city_data_df.loc[1,'Date']
date = datetime.datetime.fromtimestamp(timestamp)
print(date)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Max Latitude vs Wind Speed (m/s) " + str(date))
plt.grid()


# Save the figure
plt.savefig("zzzFig4.png")

# Show plot
plt.show()
# Out:
# 2023-04-24 00:28:26

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#*********************************************************************************************************************
#*********************************************************************************************************************
#*************NOT SURE WHAT EXACTLY IS THE QUESTION IS ASKING SO PROVIDED 2 ANSWERS***********************************
#************THE DEF LINEAR IS PROBABLY WHAT YOU ARE AFTER. ALSO HAD ISSUES WITH .STATS SO IMPORTED PEARSONR**********
#*********************************************************************************************************************
#*********************************************************************************************************************

x = city_data_df['Lat']
y = city_data_df['Wind Speed']

plt.title(f'Linear Regression of {(y.name)} vs. {(x.name)}')
plt.xlabel(x.name)
plt.ylabel(y.name)
plt.scatter(x,y)
slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
plt.plot(x, intercept + slope*x, 'r', label='Regression Line')
corr, _ = pearsonr(x, y)

print('Correlation coefficient:', corr)
print('Slope:', slope)
print('Intercept:', intercept)
print('R-value:', rvalue)
print('P-value:', pvalue)
print('Standard error:', stderr)  

# def linear_regression(city_data_df, x, y):
#     # Extract the x-axis and y-axis data from the DataFrame
##     x = city_data_df[x]
##     y = city_data_df[y]

#     # slope, intercept, correlation coefficient, and p-value for linear regression
#     slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

#     plt.scatter(x, y)
#     plt.plot(x, intercept + slope*x, 'r', label='Regression Line')
#     plt.title(f'Linear Regression of {y} vs. {x}')
#     plt.xlabel(x)
#     plt.ylabel(y)
#     plt.show()
# Out:
# Correlation coefficient: 0.09939680336520851
# Slope: 0.007514457494387057
# Intercept: 3.3329493716408143
# R-value: 0.09939680336520851
# P-value: 0.02565197087727057
# Standard error: 0.003357510140847302

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          iqaluit  63.7506  -68.5145     -0.15       100         100
# 2        flin flon  54.7682 -101.8650     -3.38        92          36
# 3           kanoya  31.3833  130.8500     17.54        58         100
# 5           kodiak  57.7900 -152.4072      0.73        55         100
# 8        iskateley  67.6803   53.1512     -6.07        90          22
#
#          Wind Speed Country        Date
# City_ID
# 0              2.57      CA  1682310506
# 2              2.48      CA  1682310506
# 3              5.88      JP  1682310506
# 5              7.72      US  1682310507
# 8              7.25      RU  1682310508

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1             punta arenas -53.1500 -70.9167      6.06        87         100
# 4               san matias -16.3667 -58.4000     22.53        88          48
# 6                grytviken -54.2811 -36.5092      1.36        81          70
# 7               vila velha -20.3297 -40.2925     22.19        89          75
# 10       port-aux-francais -49.3500  70.2167      4.34        61          97
#
#          Wind Speed Country        Date
# City_ID
# 1              5.14      CL  1682310506
# 4              0.72      BO  1682310507
# 6              9.24      GS  1682310507
# 7              1.03      BR  1682310507
# 10            14.64      TF  1682310508

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere


x = northern_hemi_df['Lat']
y = northern_hemi_df['Max Temp']

plt.title(f'Linear Regression of {(y.name)} vs. {(x.name)}')
plt.xlabel(x.name)
plt.ylabel(y.name)
plt.scatter(x,y)
slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
plt.plot(x, intercept + slope*x, 'r', label='Regression Line')
corr, _ = pearsonr(x, y)
plt.legend()


#plt.text(min(x), max(y)-5, f'y = {slope:.2f}x + {intercept:.2f}', fontsize=12)
formula_y = f'y = {slope:.2f}x + {intercept:.2f}'
plt.annotate(formula_y, xy=(0.05, 0.95), xycoords='axes fraction',color='red',fontsize=14)



print('R-value:', rvalue)
#print('P-value:', pvalue)
#print('Standard error:', stderr)
#print('Correlation coefficient:', corr)
#print('Slope:', slope)
#print('Intercept:', intercept)
# Out:
# R-value: -0.8726312327363627

# %%
# Linear regression on Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Max Temp']

plt.title(f'Linear Regression of {(y.name)} vs. {(x.name)}')
plt.xlabel(x.name)
plt.ylabel(y.name)
plt.scatter(x,y)
slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
plt.plot(x, intercept + slope*x, 'r', label='Regression Line')
corr, _ = pearsonr(x, y)
#plt.legend()


#plt.text(min(x), max(y)-5, f'y = {slope:.2f}x + {intercept:.2f}', fontsize=12)
formula_y = f'y = {slope:.2f}x + {intercept:.2f}'
plt.annotate(formula_y, xy=(0.05, 0.95), xycoords='axes fraction',color='red',fontsize=14)



print('R-value:', rvalue)
# Out:
# R-value: 0.724611664585392

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

x = northern_hemi_df['Lat']
y = northern_hemi_df['Humidity']

plt.title(f'Linear Regression of {(y.name)} vs. {(x.name)}')
plt.xlabel(x.name)
plt.ylabel(y.name)
plt.scatter(x,y)
slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
plt.plot(x, intercept + slope*x, 'r', label='Regression Line')
corr, _ = pearsonr(x, y)
plt.legend()


#plt.text(min(x), max(y)-5, f'y = {slope:.2f}x + {intercept:.2f}', fontsize=12)
formula_y = f'y = {slope:.2f}x + {intercept:.2f}'
plt.annotate(formula_y, xy=(0.05, 0.95), xycoords='axes fraction',color='red',fontsize=14)



print('R-value:', rvalue)
# Out:
# R-value: 0.034448799800358455

# %%
# Southern Hemisphere

x = southern_hemi_df['Lat']
y = southern_hemi_df['Humidity']

plt.title(f'Linear Regression of {(y.name)} vs. {(x.name)}')
plt.xlabel(x.name)
plt.ylabel(y.name)
plt.scatter(x,y)
slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
plt.plot(x, intercept + slope*x, 'r', label='Regression Line')
corr, _ = pearsonr(x, y)
plt.legend()


#plt.text(min(x), max(y)-5, f'y = {slope:.2f}x + {intercept:.2f}', fontsize=12)
formula_y = f'y = {slope:.2f}x + {intercept:.2f}'
plt.annotate(formula_y, xy=(0.05, 0.95), xycoords='axes fraction',color='red',fontsize=14)



print('R-value:', rvalue)
# Out:
# R-value: 0.23851586256232674

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Cloudiness']

plt.title(f'Linear Regression of {(y.name)} vs. {(x.name)}')
plt.xlabel(x.name)
plt.ylabel(y.name)
plt.scatter(x,y)
slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
plt.plot(x, intercept + slope*x, 'r', label='Regression Line')
corr, _ = pearsonr(x, y)
#plt.legend()


#plt.text(min(x), max(y)-5, f'y = {slope:.2f}x + {intercept:.2f}', fontsize=12)
formula_y = f'y = {slope:.2f}x + {intercept:.2f}'
plt.annotate(formula_y, xy=(0.05, 0.95), xycoords='axes fraction',color='red',fontsize=14)



print('R-value:', rvalue)
# Out:
# R-value: 0.007139155669626938

# %%
# Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Cloudiness']

plt.title(f'Linear Regression of {(y.name)} vs. {(x.name)}')
plt.xlabel(x.name)
plt.ylabel(y.name)
plt.scatter(x,y)
slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
plt.plot(x, intercept + slope*x, 'r', label='Regression Line')
corr, _ = pearsonr(x, y)
#plt.legend()


#plt.text(min(x), max(y)-5, f'y = {slope:.2f}x + {intercept:.2f}', fontsize=12)
formula_y = f'y = {slope:.2f}x + {intercept:.2f}'
plt.annotate(formula_y, xy=(0.05, 0.95), xycoords='axes fraction',color='red',fontsize=14)



print('R-value:', rvalue)
# Out:
# R-value: 0.19546159360484583

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Wind Speed']

plt.title(f'Linear Regression of {(y.name)} vs. {(x.name)}')
plt.xlabel(x.name)
plt.ylabel(y.name)
plt.scatter(x,y)
slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
plt.plot(x, intercept + slope*x, 'r', label='Regression Line')
corr, _ = pearsonr(x, y)
#plt.legend()


#plt.text(min(x), max(y)-5, f'y = {slope:.2f}x + {intercept:.2f}', fontsize=12)
formula_y = f'y = {slope:.2f}x + {intercept:.2f}'
plt.annotate(formula_y, xy=(0.05, 0.95), xycoords='axes fraction',color='red',fontsize=14)



print('R-value:', rvalue)
# Out:
# R-value: 0.13013381605315982

# %%
# Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Wind Speed']

plt.title(f'Linear Regression of {(y.name)} vs. {(x.name)}')
plt.xlabel(x.name)
plt.ylabel(y.name)
plt.scatter(x,y)
slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
plt.plot(x, intercept + slope*x, 'r', label='Regression Line')
corr, _ = pearsonr(x, y)
#plt.legend()


#plt.text(min(x), max(y)-5, f'y = {slope:.2f}x + {intercept:.2f}', fontsize=12)
formula_y = f'y = {slope:.2f}x + {intercept:.2f}'
plt.annotate(formula_y, xy=(0.05, 0.95), xycoords='axes fraction',color='red',fontsize=14)



print('R-value:', rvalue)
# Out:
# R-value: -0.28842372871815486

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
